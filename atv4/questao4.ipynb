# %%
import pandas as pd
import json

df = pd.read_json('questao_4.json')
df
# Out:
#    id_pedido                                            cliente  \
# 0         21  {'id_cliente': 121, 'nome_cliente': 'Ursula Ca...
# 1         22  {'id_cliente': 122, 'nome_cliente': 'Victor An...
# 2         23  {'id_cliente': 123, 'nome_cliente': 'Wagner Ne...
# 3         24  {'id_cliente': 124, 'nome_cliente': 'Xavier Al...
# 4         25  {'id_cliente': 125, 'nome_cliente': 'Yasmin Di...
#
#                                      detalhes_compra data_pedido     status
# 0  {'produto': {'id_produto': 221, 'nome_produto'...  2025-01-21   Entregue
# 1  {'produto': {'id_produto': 222, 'nome_produto'...  2025-01-22   Pendente
# 2  {'produto': {'id_produto': 223, 'nome_produto'...  2025-01-23   Entregue
# 3  {'produto': {'id_produto': 224, 'nome_produto'...  2025-01-24   Entregue
# 4  {'produto': {'id_produto': 225, 'nome_produto'...  2025-01-25  Cancelado

# %%
with open('questao_4.json', 'r') as file:
    data = json.load(file)
data
# Out:
# [{'id_pedido': 21,
#   'cliente': {'id_cliente': 121, 'nome_cliente': 'Ursula Castro'},
#   'detalhes_compra': {'produto': {'id_produto': 221,
#     'nome_produto': 'SandÃ¡lia Feminina',
#     'categoria': 'CalÃ§ados'},
#    'quantidade': 1,
#    'preco_unitario': 90.0,
#    'preco_total': 90.0},
#   'data_pedido': '2025-01-21',
#   'status': 'Entregue'},
#  {'id_pedido': 22,
#   'cliente': {'id_cliente': 122, 'nome_cliente': 'Victor Andrade'},
#   'detalhes_compra': {'produto': {'id_produto': 222,
#     'nome_produto': 'Chuteira',
#     'categoria': 'Esportes'},
#    'quantidade': 1,
#    'preco_unitario': 230.0,
#    'preco_total': 230.0},
#   'data_pedido': '2025-01-22',
#   'status': 'Pendente'},
#  {'id_pedido': 23,
#   'cliente': {'id_cliente': 123, 'nome_cliente': 'Wagner Neves'},
#   'detalhes_compra': {'produto': {'id_produto': 223,
#     'nome_produto': 'Carregador PortÃ¡til',
#     'categoria': 'EletrÃ´nicos'},
#    'quantidade': 1,
#    'preco_unitario': 100.0,
# ...

# %%
df = pd.json_normalize(data, sep='_')
df
# Out:
#    id_pedido data_pedido     status  cliente_id_cliente cliente_nome_cliente  \
# 0         21  2025-01-21   Entregue                 121        Ursula Castro
# 1         22  2025-01-22   Pendente                 122       Victor Andrade
# 2         23  2025-01-23   Entregue                 123         Wagner Neves
# 3         24  2025-01-24   Entregue                 124       Xavier Almeida
# 4         25  2025-01-25  Cancelado                 125          Yasmin Dias
#
#    detalhes_compra_produto_id_produto detalhes_compra_produto_nome_produto  \
# 0                                 221                   SandÃ¡lia Feminina
# 1                                 222                             Chuteira
# 2                                 223                 Carregador PortÃ¡til
# 3                                 224                      Bola de Futebol
# 4                                 225                   Maquiagem Completa
#
# ...
